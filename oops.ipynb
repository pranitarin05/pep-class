# %% [markdown]
# <a href="https://colab.research.google.com/github/pranitarin05/pep-class/blob/main/oops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#inheritance
#one class user another class properties fucntion
class human:
  def eat(self):
    print("human can eat")
class student(human):
  def study(self):
    print("student can study ")
s1=student()
s1.eat()
s1.study()
# Out:
# human can eat
# student can study

# %%
#inheritance code of animal can speak and dog can bark
class animal:
  def speak(self):
    print("animal can speak")
class dog(animal):
  def bark(self):
    print("dogs bark")
d1=dog()
d1.speak()
d1.bark()
# Out:
# animal can speak
# dogs bark

# %%
#inheriting cod of parent > nokia >call
                   #child>i phone> call,internet
class nokia:
  def nokia(self):
    print("nokia can call")
class iphone(nokia):
  def internet(self):
    print("iphone hv internet")
n1=iphone()
n1.nokia()
n1.internet()
# Out:
# nokia can call
# iphone hv internet

# %%
#use of key word super #incomplete
class Parent:
  print("this is parent constructer")
class Child(Parent):
  def __init__(self):
    super().__init__()
    print("i will")
obj=child()
# Out:
# this is parent constructer

# %%
#method over riding
class parent:
  def work(self):
    print(" will go to work ")
class child(parent):
  def  work(self):
    print("i will go to school")
obj=child()
obj.work()
# Out:
# i will go to school

# %%
# class father and mother and then put function in it and then try extract the functuion in child class
class Father:
  def beat(self):
    print("father beats")
class Mother:
  def love(self):
    print("mother loves")
class Child(Father,Mother):
  def cry(self):
    print("happy and crying")
s1=Child()
s1.beat()
s1.love()
s1.cry()
# Out:
# father beats
# mother loves
# happy and crying

# %%
#create a parent class a function in it and a child class a function in it
#check weather its over ride and then inherti using super
class car():
  def run(self):
    print("car runs ")
class bike(car):
  def __init__(self):
    super().__init__()
    print("cycle")
obj=bike()
obj.run()
# Out:
# cycle
# car runs

# %%
class Teacher():
  def teaching(self):
    print("he is teaching")
class Coder(Teacher):
  def coding(self):
    print("codes")
class Student(Coder):
  pass
s1=Student()
s1.teaching()
s1.coding()
# Out:
# he is teaching
# codes

# %%
class Parent:
  def __init__(self):
    self.__x=10
class Child(parent):
  def show(self):
    print(self._Parent__x)

obj=child()
obj.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1719682296.py in <cell line: 0>()
#       7
#       8 obj=child()
# ----> 9 obj.show()
#
# AttributeError: 'child' object has no attribute 'show'

# %%
class parent:
  def __init__(self):
    self._x=100
class child(parent):
  def show(self):
    print(self._x)
obj=child()
obj.show()

# %%
#encapsulation problem : create a parent class name person then variable name private and have the constructer to set
#method : get_name() to return the name
#make class student (child) this will inherit persom then it has method "show_name() showing names using parent method
#create a object student and display name
class Person:
  def __init__(self,name):
    self.__name=names
  def get_names(self):
    return self.__name
class Student(person):
  def show_name(self):
    print("my name is", self.get_name())
s1=Student("karan")
s1.show_name()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3949315057.py in <cell line: 0>()
#       8   def get_names(self):
#       9     return self.__name
# ---> 10 class Student(person):
#      11   def show_name(self):
#      12     print("my name is", self.get_name())
#
# NameError: name 'person' is not defined

# %%
#diamond problem
class A:
  def Ab(self):
    print("B")
class B(A):
  def Ab(self):
    print("c")
class C(A):
  def Ab(self):
    print("D")
class D(B,C):
  def Ab(self):
    print("E")
s1=D()

s1.Ab()
# Out:
# E

# %%
#polymorphism
class dog:
  def speak(self):
    print("dog barks")
class cat:
  def speak(self):
    print("cat meows")
d1=dog()
d1.speak()
c1=cat()
c1.speak()
# Out:
# dog barks
# cat meows

# %%
#polymorphism
class Human:
  def speak(self):
    print("human speaks")
class Baby:
  def speak(self):
    print("baby is crying")
class Dog:
  def speak(self):
    print("dog is barking")
#polymorphism in action
h=Human()
b=Baby()
d=Dog()
h.speak()
b.speak()
d.speak()
# Out:
# human speaks
# baby is crying
# dog is barking

# %%
class person:
  def role(self):
# Out:
#   File "/tmp/ipython-input-236256133.py", line 2
#     def role(self):
#                    ^
# SyntaxError: incomplete input

# %%
#abstarction
# define rules, show what to do , hidws how to do , uses in a big problem
#method name is present method body is absent and child will complete the metnof body
class parent:
  def work(self):
    pass
class child(parent):
  def work(self):
    print("working")


c = child()
c.work()
# Out:
# working

# %%
#abstarction
class Payment:
  def Pay(self,amount):
    pass
class Upi(Payment):
  def Pay(self,amount):
    print(amount,"paid using upi")
df=Upi()
df.Pay(100)
# Out:
# 100 paid using upi

# %%
#abstarction
class Payment:
  def Pay(self,amount):
    pass
class Cash(Payment):
  def Pay(self,amount):
    print(amount, "paid using by cash")
class Cheq(Payment):
  def Pay(self,amount):
    print(amount, "paid using bank check ")

s1=Cheq()
s2=Cash()
s1.Pay(300)
s2.Pay(500)
# Out:
# 300 paid using bank check
# 500 paid using by cash

# %%
#interface
class payment:
  pass
class Cash(Payment):
  def Pay(self,amount):
    print(amount, "paid using by cash")
class Cheq(Payment):
  def Pay(self,amount):
    print(amount, "paid using bank check ")
s1=Cheq()
s2=Cash()
s1.Pay(300)
s2.Pay(500)
# Out:
# 300 paid using bank check
# 500 paid using by cash

# %%
#make a abstract class "course" it has two method "info" and "duration" then create an interface name exam "interface" has a
#method exam_type()
#python_course which is child class of both and then continuing that also add java_course
class Course:
  def course_info(self):
    pass
  def duration(self):
    pass
class ExamInterface:
  def exam_type(self):
    pass
class Python(Course, ExamInterface):
  def duration(self):
    print("course duration is 3 months")
  def exam_type(self):
    print("this is a practical based")
c=Python()
c.course_info()
c.duration()
c.exam_type() # Corrected: Changed c.exam.type() to c.exam_type()
# Out:
# course duration is 3 months
# this is a practical based

# %%
#composition
class Adress:
  def __init__(self,city):
    self.city=city
  def show_address(self):
    print("city", self.city)
#student class
class Student:
  def __init__(self,name,city):
    self.name=name
    #composition
    #creating object of adress ckass inside student class
    self.address=Adress(city)
  def show_student(self):
    print("NAme:",self.name)
    #using object of another class
    self.address.show_address()

s=Student("karan", "Delhi")
s.show_student()
# Out:
# NAme: karan
# city Delhi
